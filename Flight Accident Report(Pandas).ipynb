# %% [markdown]
# # Flight Crash Report

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\acer.DESKTOP-1VQGBE7\OneDrive\Desktop\flight.csv")
df
# Out:
#        num        acc.date                                 type        reg  \
# 0        0       03-Jan-22  British Aerospace 4121 Jetstream 41     ZS-NRJ
# 1        1       04-Jan-22  British Aerospace 3101 Jetstream 31     HR-AYY
# 2        2       05-Jan-22                       Boeing 737-4H6     EP-CAP
# 3        3       08-Jan-22                  Tupolev Tu-204-100C   RA-64032
# 4        4       12-Jan-22        Beechcraft 200 Super King Air        NaN
# ...    ...             ...                                  ...        ...
# 2495  1245       20-Dec-18                Cessna 560 Citation V     N188CW
# 2496  1246       22-Dec-18              PZL-Mielec M28 Skytruck  GNB-96107
# 2497  1247       24-Dec-18                       Antonov An-26B     9T-TAB
# 2498  1248       31-Dec-18                  Boeing 757-2B7 (WL)     N938UW
# 2499  1249  unk. date 2018               Rockwell Sabreliner 80     N337KL
#
#                                                operator fat  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   num       2500 non-null   int64
#  1   acc.date  2500 non-null   object
#  2   type      2500 non-null   object
#  3   reg       2408 non-null   object
#  4   operator  2486 non-null   object
#  5   fat       2488 non-null   object
#  6   location  2500 non-null   object
#  7   dmg       2500 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 156.4+ KB

# %%
df['fat'] = pd.to_numeric(df['fat'],errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   num       2500 non-null   int64
#  1   acc.date  2500 non-null   object
#  2   type      2500 non-null   object
#  3   reg       2408 non-null   object
#  4   operator  2486 non-null   object
#  5   fat       2450 non-null   float64
#  6   location  2500 non-null   object
#  7   dmg       2500 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 156.4+ KB

# %%
df.head(10)
# Out:
#    num   acc.date                                   type       reg  \
# 0    0  03-Jan-22    British Aerospace 4121 Jetstream 41    ZS-NRJ
# 1    1  04-Jan-22    British Aerospace 3101 Jetstream 31    HR-AYY
# 2    2  05-Jan-22                         Boeing 737-4H6    EP-CAP
# 3    3  08-Jan-22                    Tupolev Tu-204-100C  RA-64032
# 4    4  12-Jan-22          Beechcraft 200 Super King Air       NaN
# 5    5  16-Jan-22                   Airbus A320-214 (WL)    JA24MC
# 6    6  19-Jan-22           Cessna 208B Grand Caravan EX    YV3033
# 7    7  22-Jan-22                        Airbus A320-232    N760JB
# 8    8  27-Jan-22  Bombardier CL-600-2B16 Challenger 604    2-SLOW
# 9    9  31-Jan-22  Bombardier CL-600-2B16 Challenger 604    N999PX
#
#                                         operator  fat  \
# 0                                     SA Airlink  0.0
# 1  LANHSA - Línea Aérea Nacional de Honduras S.A  0.0
# 2                               Caspian Airlines  0.0
# ...

# %%
df.isnull().sum()
# Out:
# num          0
# acc.date     0
# type         0
# reg         92
# operator    14
# fat         50
# location     0
# dmg          0
# dtype: int64

# %%
df = df.dropna(subset = 'reg')
df = df.dropna(subset = 'operator')
df['fat'] = df['fat'].fillna('No Records')
df
# Out:
#        num        acc.date                                 type        reg  \
# 0        0       03-Jan-22  British Aerospace 4121 Jetstream 41     ZS-NRJ
# 1        1       04-Jan-22  British Aerospace 3101 Jetstream 31     HR-AYY
# 2        2       05-Jan-22                       Boeing 737-4H6     EP-CAP
# 3        3       08-Jan-22                  Tupolev Tu-204-100C   RA-64032
# 5        5       16-Jan-22                 Airbus A320-214 (WL)     JA24MC
# ...    ...             ...                                  ...        ...
# 2495  1245       20-Dec-18                Cessna 560 Citation V     N188CW
# 2496  1246       22-Dec-18              PZL-Mielec M28 Skytruck  GNB-96107
# 2497  1247       24-Dec-18                       Antonov An-26B     9T-TAB
# 2498  1248       31-Dec-18                  Boeing 757-2B7 (WL)     N938UW
# 2499  1249  unk. date 2018               Rockwell Sabreliner 80     N337KL
#
#                                                operator  fat  \
# ...

# %%
df = df.loc[:1249]
df
# Out:
#        num        acc.date                                 type        reg  \
# 0        0       03-Jan-22  British Aerospace 4121 Jetstream 41     ZS-NRJ
# 1        1       04-Jan-22  British Aerospace 3101 Jetstream 31     HR-AYY
# 2        2       05-Jan-22                       Boeing 737-4H6     EP-CAP
# 3        3       08-Jan-22                  Tupolev Tu-204-100C   RA-64032
# 5        5       16-Jan-22                 Airbus A320-214 (WL)     JA24MC
# ...    ...             ...                                  ...        ...
# 1245  1245       20-Dec-18                Cessna 560 Citation V     N188CW
# 1246  1246       22-Dec-18              PZL-Mielec M28 Skytruck  GNB-96107
# 1247  1247       24-Dec-18                       Antonov An-26B     9T-TAB
# 1248  1248       31-Dec-18                  Boeing 757-2B7 (WL)     N938UW
# 1249  1249  unk. date 2018               Rockwell Sabreliner 80     N337KL
#
#                                                operator  fat  \
# ...

# %%
df[df['acc.date'] == '08-Jan-22']
# Out:
#    num   acc.date                 type       reg                  operator  \
# 3    3  08-Jan-22  Tupolev Tu-204-100C  RA-64032  Cainiao, opb Aviastar-TU
#
#    fat                                       location  dmg
# 3  0.0  Hangzhou Xiaoshan International Airport (HGH)  w/o

# %%
df[df['dmg'] == 'w/o']
# Out:
#        num   acc.date                                      type       reg  \
# 3        3  08-Jan-22                       Tupolev Tu-204-100C  RA-64032
# 16      16  11-Feb-22                             Antonov An-2R  RA-33599
# 17      17  14-Feb-22                           Let L-410UVP-E3    9S-GFA
# 27      27  24-Feb-22                         Antonov An-26-100  UR-13395
# 28      28  24-Feb-22                            Antonov An-74T  UR-74010
# ...    ...        ...                                       ...       ...
# 1234  1234  06-Dec-18                   Lockheed Martin KC-130J    167981
# 1238  1238  08-Dec-18  Pilatus Britten-Norman BN-2A-20 Islander    VH-OBL
# 1244  1244  20-Dec-18                            Antonov An-26B    9S-AGB
# 1245  1245  20-Dec-18                     Cessna 560 Citation V    N188CW
# 1247  1247  24-Dec-18                            Antonov An-26B    9T-TAB
#
#                                                operator  fat  \
# ...

# %%
df = df.drop('num', axis = 1)
df
# Out:
#             acc.date                                 type        reg  \
# 0          03-Jan-22  British Aerospace 4121 Jetstream 41     ZS-NRJ
# 1          04-Jan-22  British Aerospace 3101 Jetstream 31     HR-AYY
# 2          05-Jan-22                       Boeing 737-4H6     EP-CAP
# 3          08-Jan-22                  Tupolev Tu-204-100C   RA-64032
# 5          16-Jan-22                 Airbus A320-214 (WL)     JA24MC
# ...              ...                                  ...        ...
# 1245       20-Dec-18                Cessna 560 Citation V     N188CW
# 1246       22-Dec-18              PZL-Mielec M28 Skytruck  GNB-96107
# 1247       24-Dec-18                       Antonov An-26B     9T-TAB
# 1248       31-Dec-18                  Boeing 757-2B7 (WL)     N938UW
# 1249  unk. date 2018               Rockwell Sabreliner 80     N337KL
#
#                                                operator  fat  \
# 0                                            SA Airlink  0.0
# ...

# %%
df.groupby('dmg').agg({'acc.date':['count'],'fat':['max','min','mean','count','sum']})
# Out:
#     acc.date    fat
#        count    max  min      mean count     sum
# dmg
# min       48    1.0  0.0  0.021739    46     1.0
# mis        1    NaN  NaN       NaN     0     0.0
# non      161    1.0  0.0  0.006289   159     1.0
# sub      661   19.0  0.0  0.059542   655    39.0
# unk       14    0.0  0.0  0.000000    14     0.0
# w/o      318  257.0  0.0  7.228758   306  2212.0

# %%
df.groupby('operator').sum(numeric_only = True).sort_values(by = 'fat',ascending = False)
# Out:
#                                       fat
# operator
# Al Quwwat al-Jawwiya al-Jaza'eriya  258.0
# Lion Air                            189.0
# Ukraine International Airlines      176.0
# Ethiopian Airlines                  157.0
# China Eastern Airlines              132.0
# ...                                   ...
# Flybe                                 0.0
# Flybondi                              0.0
# Flyzar                                0.0
# Força Aérea Brasileira - FAB          0.0
# Kazairtrans Airline                   0.0
#
# [815 rows x 1 columns]

# %%
df.groupby('operator').sum(numeric_only = True).sort_values(by = 'fat',ascending = False).head(5).plot(figsize = (15,5))
# Out:
# <Axes: xlabel='operator'>

# %%
df.groupby('dmg').sum(numeric_only = True).plot(kind = 'bar')
# Out:
# <Axes: xlabel='dmg'>

# %%
df.to_excel(r"C:\Users\acer.DESKTOP-1VQGBE7\OneDrive\Desktop\updated_flight.xlsx",index = False)
